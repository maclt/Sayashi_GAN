# %%
# !kill -9 -1

# %%
# memory footprint support libraries/code
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize
import psutil
import humanize
import os
import GPUtil as GPU
GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0]
def printm():
    process = psutil.Process(os.getpid())
    print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " | Proc size: " + humanize.naturalsize( process.memory_info().rss))
    print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
printm()
# Out:
# Collecting gputil
#   Downloading https://files.pythonhosted.org/packages/45/99/837428d26b47ebd6b66d6e1b180e98ec4a557767a93a81a02ea9d6242611/GPUtil-1.3.0.tar.gz
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from gputil) (1.14.6)
# Building wheels for collected packages: gputil
# done
#   Stored in directory: /root/.cache/pip/wheels/17/0f/04/b79c006972335e35472c0b835ed52bfc0815258d409f560108
# Successfully built gputil
# Installing collected packages: gputil
# Successfully installed gputil-1.3.0
# Requirement already satisfied: psutil in /usr/local/lib/python3.6/dist-packages (5.4.7)
# Collecting humanize
#   Downloading https://files.pythonhosted.org/packages/8c/e0/e512e4ac6d091fc990bbe13f9e0378f34cf6eecd1c6c268c9e598dcf5bb9/humanize-0.5.1.tar.gz
# Building wheels for collected packages: humanize
# done
#   Stored in directory: /root/.cache/pip/wheels/69/86/6c/f8b8593bc273ec4b0c653d3827f7482bb2001a2781a73b7f44
# Successfully built humanize
# Installing collected packages: humanize
# Successfully installed humanize-0.5.1
# Gen RAM Free: 12.7 GB  | Proc size: 138.6 MB
# GPU RAM Free: 11439MB | Used: 0MB | Util   0% | Total 11439MB

# %%
# !pip install -U -q PyDrive

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
# https://drive.google.com/drive/folders/<ID>
dir_id = "1DLqYGQKx4tMHDEy85lVfgfxHLC-RNRqJ"

# フォルダ内にあるファイル名とファイルIDを表示する
file_list = drive.ListFile({'q': "'%s' in parents and trashed=false" % dir_id}).GetList()
for f in file_list:
  print("name: " + f["title"] + ", id: " + f["id"])
# Out:
# name: sayashi4.ipynb, id: 1dqmzbu9G4XPKs1jD3UsCqFGP8x0QyF21
# name: sayashi3.ipynb, id: 18qjc2GqdZG_W6EfrfyiIIS6YXjmceFul
# name: this_is_sayashi, id: 1VoMM2o-_qNbZirO9141nCIyr1JorJvrS
# name: tihs_is_karin.zip, id: 1bCAcif-NB_H76mYDW4cGKnGB4QoiM8IH
# name: tihs_is_karin, id: 1Yr4B6KLt33KpoIglzEuF1EVkhPPKrA21
# name: this_is_sayumi, id: 1gzWZwH49NhB7qMT49p4A0r05cgFDtPem
# name: this_is_sayumi.zip, id: 1SvOeSS3iufFJ0w50ruf0BWFyjRNebMQL
# name: this_is_sayasi.zip, id: 19Tvm2uQONnRKSkBYFNsjqK2zVAiJZxgq
# name: sayashi1.ipynb, id: 1_He9NhDrrke3aGrTUCc4mX8oTkUaTULs
# name: sayashi2.ipynb, id: 1U1EcBwPu4vkwo00CwA6bj0-Y8K_QZHjT
# name: NungNa.jpg, id: 1nUsyYc1pr8KV1Q7F9MiOkR5Uw1_wpads
# name: this_isnt_sayashi.zip, id: 1BgbzXwpffyDcrzrTzNgNkWsjgenFkx0R
# name: PythonStan1.ipynb, id: 1u_bzChP3uV3ebJvTx4IiFkUczMa_8Gx_
# name: DL4US6-5.ipynb, id: 14vjyHHXDtBwOuHqx0e_MGha_yUiLtdDe
# name: DL4US6-3.ipynb, id: 10n1UZfukZtfAmwLweQ0Qn3Zh-tEAonc8
# name: DL4US6-1.ipynb, id: 1a5KXk4afIeQXUi8CB4sgWyKmfoEGlxhX
# name: DL4US5-4.ipynb, id: 1-d5TlWEivprO6KRdab7gAVokqGnvLA88
# name: DL4US5_1.ipynb, id: 1MPfbgkdWt1xPeulf2LNfY3Z48JtrISuL
# name: DL4US5_2.ipynb, id: 1hN9pf7YNbI5vRFH5xxoXp3Vlb78waDF3
# name: Titanic.ipynb, id: 1gj2WihFFcM57zju60SzDBCJxbQKbiu9U
# name: train.csv, id: 1B8MUANMMC6t8Rn4XaHUM5MWm4T6geFNw
# name: DL4US4_1.ipynb, id: 1-3JkV7QlbUvJlsaVkba8eQHTRnkvGBZE
# name: DL4US4_2.ipynb, id: 1179vEQ-bgMpmHt-SeskAK9cV7EV3fPI-
# name: DL4US4_4.ipynb, id: 1upVMnLeRjTdi7-9wvvq6xDKhY5CB3YTQ
# name: DL4US3_2.ipynb, id: 1qVEtsNk7OKt75y4H1Sr5VEkf4lKKfcTY
# name: DL4US3_4.ipynb, id: 1BOTGlVo0p4iNy_IOV9FuG9vamsr0UqP9
# name: DL4US_2-2.ipynb, id: 1ze9jbaw_mKuSB_mBlFC9Tj71XtlZdqm-
# name: DL4US_2-1.ipynb, id: 1O3R83ViQMqFFN-UfNZAbqSw2vDj4qz98
# name: DL4US2_4.ipynb, id: 1Xuh_D_E5d6B_8VCXBYPIfALjIGQJfDgw
# name: DL4US2_3.ipynb, id: 15wSxG6eBm8idT662L0pJeJez8XThR-a0
# name: DL4US_1-4.ipynb, id: 1fDCYRCsRp76O8Nu7QOpZv34BNI4WocS0
# name: DL4US_1-3.ipynb, id: 19oNBX-FMvlLX2wGmh0cUriw5VVEGz8ps
# name: DL4US_1-1.ipynb, id: 1CN1zXlhE-eT9D8xhVG3hg3UG4mVy9x5W
# name: DL4US_1-2.ipynb, id: 1LLok45sfybEUb-a8OTqCwCVyXTe5A_ws
# name: deep_learning2-2.ipynb, id: 1QiwE2uBmXqGy89Wx9B6N9meFZBef2XpG
# name: deep_learning2-1.ipynb, id: 1L2t-4rBrOl59OOl1liTvG80dxymvfXo2
# name: deep_learning1-1.ipynb, id: 1i9RbyG4QcTm6ZVGlVXW9LgO9itQ2q1UL
# name: deep_learning1-2.ipynb, id: 1p9pM0vOMsNWTTOIDACIQ0Mt_e3oL6LB2
# name: deep_learning1-3.ipynb, id: 1wKcafwp1pY39HkyR8V-ZmEcbnSrInYzT
# name: AIAcademy_dl_sample, id: 1Vz3pNVMYqrwp6xGubDYoE11iY3NWGPLd

# %%
# 鞘師のデータを取得
id = '1h7UdJxcTZjg-KfIHk1NfjAa3dCKAd4Co'  # 共有リンクで取得した id= より後の部分
downloaded = drive.CreateFile({'id': id})
downloaded.GetContentFile('this_is_sayashi.zip')

# %%
! mkdir this_is_sayashi
# !unzip this_is_sayashi.zip -d this_is_sayashi
# Out:
# Archive:  this_is_sayashi.zip
#   inflating: this_is_sayashi/sayashi35840285.jpg
#   inflating: this_is_sayashi/sayashi83109433.jpg
#   inflating: this_is_sayashi/sayashi45463267.jpg
#   inflating: this_is_sayashi/sayashi72557221.jpg
#   inflating: this_is_sayashi/sayashi40322537.jpg
#   inflating: this_is_sayashi/sayashi93388853.jpg
#   inflating: this_is_sayashi/sayashi89457331.jpg
#   inflating: this_is_sayashi/sayashi27793999.jpg
#   inflating: this_is_sayashi/sayashi70996137.jpg
#   inflating: this_is_sayashi/sayashi16296500.jpg
#   inflating: this_is_sayashi/sayashi86806740.jpg
#   inflating: this_is_sayashi/sayashi18593576.jpg
#   inflating: this_is_sayashi/sayashi70720298.jpg
#   inflating: this_is_sayashi/sayashi77362238.jpg
#   inflating: this_is_sayashi/sayashi40318049.jpg
#   inflating: this_is_sayashi/sayashi44501673.jpg
#   inflating: this_is_sayashi/sayashi39308642.jpg
#   inflating: this_is_sayashi/sayashi49562664.jpg
#   inflating: this_is_sayashi/sayashi65952674.jpg
#   inflating: this_is_sayashi/sayashi75445458.jpg
#   inflating: this_is_sayashi/sayashi06216547.jpg
#   inflating: this_is_sayashi/sayashi09127399.jpg
#   inflating: this_is_sayashi/sayashi63169663.jpg
#   inflating: this_is_sayashi/sayashi71028599.jpg
#   inflating: this_is_sayashi/sayashi78282772.jpg
#   inflating: this_is_sayashi/sayashi85212317.jpg
#   inflating: this_is_sayashi/sayashi69069599.jpg
#   inflating: this_is_sayashi/sayashi22876137.jpg
#   inflating: this_is_sayashi/sayashi76415845.jpg
#   inflating: this_is_sayashi/sayashi57592526.jpg
#   inflating: this_is_sayashi/sayashi81653878.jpg
#   inflating: this_is_sayashi/sayashi38060718.jpg
#   inflating: this_is_sayashi/sayashi72194132.jpg
#   inflating: this_is_sayashi/sayashi15157103.jpg
#   inflating: this_is_sayashi/sayashi61699953.jpg
#   inflating: this_is_sayashi/sayashi50112405.jpg
#   inflating: this_is_sayashi/sayashi62574314.jpg
#   inflating: this_is_sayashi/sayashi40280979.jpg

# %%
! rm -r this_is_sayashi/__MACOSX/

# %%
# 道重のデータを取得
id = '1SvOeSS3iufFJ0w50ruf0BWFyjRNebMQL'  # 共有リンクで取得した id= より後の部分
downloaded = drive.CreateFile({'id': id})
downloaded.GetContentFile('this_is_sayumi.zip')

# %%
! mkdir this_is_sayumi
! unzip this_is_sayumi.zip -d this_is_sayumi
# Out:
# Archive:  this_is_sayumi.zip
#    creating: this_is_sayumi/this_is_sayumi/
#   inflating: this_is_sayumi/this_is_sayumi/sayumi48301461.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi23415456.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi35548909.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi70876415.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi10357941.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi57457295.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi11966054.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi20402903.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi07479569.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi74103074.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi44136572.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi74056713.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi36843364.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi88659054.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi44072668.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi78374422.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi85905325.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi95753112.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi48746480.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi32957396.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi02629129.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi12825789.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi72437451.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi78761184.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi89754288.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi60745293.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi15978832.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi54084351.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi22481653.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi97229420.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi26908653.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi01776143.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi63370809.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi39262116.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi37714268.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi41625837.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi47406473.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi90993469.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi78157042.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi52141962.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi02447918.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi51891845.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi72661451.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi72336932.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi30889327.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi57175821.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi07952944.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi88167269.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi41628057.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi39988283.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi30621659.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi83944433.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi31094437.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi78801278.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi51032994.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi71579679.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayumi32320734.jpg
#   inflating: this_is_sayumi/this_is_sayumi/.DS_Store
#    creating: this_is_sayumi/__MACOSX/
#    creating: this_is_sayumi/__MACOSX/this_is_sayumi/
#   inflating: this_is_sayumi/__MACOSX/this_is_sayumi/._.DS_Store
#   inflating: this_is_sayumi/this_is_sayumi/sayumi30466814.jpg
#   inflating: this_is_sayumi/this_is_sayumi/sayum
jpg
#   inflating: this_is_karin/tihs_is_karin/karin15319871.jpg
#   inflating: this_is_karin/tihs_is_karin/karin08402452.jpg
#   inflating: this_is_karin/tihs_is_karin/karin41487112.jpg
#   inflating: this_is_karin/tihs_is_karin/karin73519818.jpg
#   inflating: this_is_karin/tihs_is_karin/karin75299115.jpg
#   inflating: this_is_karin/tihs_is_karin/karin51475101.jpg
#   inflating: this_is_karin/tihs_is_karin/karin59995538.jpg
#   inflating: this_is_karin/tihs_is_karin/karin67868856.jpg
#   inflating: this_is_karin/tihs_is_karin/karin55741502.jpg
#   inflating: this_is_karin/tihs_is_karin/karin84441928.jpg
#   inflating: this_is_karin/tihs_is_karin/karin54653207.jpg
#   inflating: this_is_karin/tihs_is_karin/karin47877691.jpg
#   inflating: this_is_karin/tihs_is_karin/karin31441872.jpg
#   inflating: this_is_karin/tihs_is_karin/karin21570023.jpg
#   inflating: this_is_karin/tihs_is_karin/karin39616632.jpg
#   inflating: this_is_karin/tihs_is_karin/karin53749574.jpg
#   inflating: this_is_karin/tihs_is_karin/karin18468802.jpg
#   inflating: this_is_karin/tihs_is_karin/karin79221994.jpg
#   inflating: this_is_karin/tihs_is_karin/karin92514566.jpg
#   inflating: this_is_karin/__MACOSX/tihs_is_karin/._karin92514566.jpg
#   inflating: this_is_karin/tihs_is_karin/karin78303834.jpg
#   inflating: this_is_karin/tihs_is_karin/karin15340124.jpg
#   inflating: this_is_karin/tihs_is_karin/karin32597233.jpg
#   inflating: this_is_karin/tihs_is_karin/karin03677514.jpg
#   inflating: this_is_karin/tihs_is_karin/karin60648491.jpg
#   inflating: this_is_karin/tihs_is_karin/karin41177759.jpg
#   inflating: this_is_karin/tihs_is_karin/karin86141021.jpg
#   inflating: this_is_karin/tihs_is_karin/karin76255066.jpg
#   inflating: this_is_karin/tihs_is_karin/karin82950514.jpg
#   inflating: this_is_karin/tihs_is_karin/karin52846573.jpg
#   inflating: this_is_karin/tihs_is_karin/karin44283733.jpg
#   inflating: this_is_karin/tihs_is_karin/karin65222301.jpg
#   inflating: this_is_karin/tihs_is_karin/karin88178654.jpg
#   inflating: this_is_karin/tihs_is_karin/karin05652963.jpg
#   inflating: this_is_karin/tihs_is_karin/karin45092791.jpg
#   inflating: this_is_karin/tihs_is_karin/karin38074933.jpg
#   inflating: this_is_karin/tihs_is_karin/karin84242882.jpg

# %%
! rm -r this_is_karin/__MACOSX/

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from keras.preprocessing.image import array_to_img, img_to_array, list_pictures, load_img
from PIL import Image
# Out:
# Using TensorFlow backend.

# %%
from keras.layers import Input
from keras.layers.core import Reshape, Dense, Flatten, Activation
from keras.layers.convolutional import Conv2D, UpSampling2D
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.normalization import BatchNormalization
from keras.models import Model

def Generator():
    nch = 256
    model_input = Input(shape=[100])
    x = Dense(nch* 50 * 50, kernel_initializer='glorot_normal')(model_input) # 100 -> 200*50*50
    x = BatchNormalization()(x)
    x = LeakyReLU(0.2)(x)
    x = Reshape( [50, 50, nch] )(x) # 200*50*50 -> 50x50x200 (width)x(height)x(channel)
    x = UpSampling2D(size=(2, 2))(x) # 50x50x200 -> 100x100x200
    x = Conv2D(int(nch/2), (2, 2), padding='same', kernel_initializer='glorot_uniform')(x) # 100x100x256 -> 100x100x128
    x = BatchNormalization()(x)
    x = LeakyReLU(0.2)(x)
    x = Conv2D(int(nch/4), (2, 2), padding='same', kernel_initializer='glorot_uniform')(x) # 100x100x128 -> 100x100x64
    x = BatchNormalization()(x)
    x = LeakyReLU(0.2)(x)
    x = Conv2D(int(nch/8), (3, 3), padding='same', kernel_initializer='glorot_uniform')(x) # 100x100x64 -> 100x100x32
    x = BatchNormalization()(x)
    x = LeakyReLU(0.2)(x)
    x = Conv2D(3, (3, 3), padding='same', kernel_initializer='glorot_uniform')(x) # 100x100x64 -> 100x100x3
    model_output = Activation('tanh')(x)
    model = Model(model_input, model_output)
    model.summary()
    
    return model

# %%
from keras.layers import Input
from keras.layers.core import Reshape, Dense, Dropout, Flatten
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import Conv2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.models import Model

def Discriminator(shape, dropout_rate=0.25, opt=Adam(lr=1e-4)):
    model_input = Input(shape=shape) # 100x100x3
    x = Conv2D(32, (3, 3), padding='same', kernel_initializer='glorot_uniform', strides=(2, 2))(model_input) # 100x100x3 -> 50x50x32
    x = LeakyReLU(0.2)(x)
    x = Dropout(dropout_rate)(x)
    x = Conv2D(64, (3, 3), padding='same', kernel_initializer='glorot_uniform', strides=(2, 2))(x) # 50x50x32 -> 25x25x64
    x = LeakyReLU(0.2)(x)
    x = Dropout(dropout_rate)(x)
    x = Conv2D(128, (3, 3), padding='same', kernel_initializer='glorot_uniform', strides=(2, 2))(x) # 25x25x64 -> 13x13x128
    x = LeakyReLU(0.2)(x)
    x = Dropout(dropout_rate)(x)
    x = Conv2D(256, (3, 3), padding='same', kernel_initializer='glorot_uniform', strides=(2, 2))(x) # 13x13x128 -> 7x7x256
    x = LeakyReLU(0.2)(x)
    x = Dropout(dropout_rate)(x)
    x = Conv2D(512, (3, 3), padding='same', kernel_initializer='glorot_uniform', strides=(2, 2))(x) # 7x7x256 -> 4x4x512
    x = LeakyReLU(0.2)(x)
    x = Dropout(dropout_rate)(x)
    x = Flatten()(x) # 1x1x512 -> 1*1*256
    x = Dense(256)(x)
    x = LeakyReLU(0.2)(x)
    x = Dropout(dropout_rate)(x)
    model_output = Dense(2,activation='softmax')(x) # 256 -> 2
    model = Model(model_input, model_output)
    model.compile(loss='categorical_crossentropy', optimizer=opt)
    model.summary()
    
    return model

# %%
from keras.layers import Input
from keras.models import Model

def combined_network(generator, discriminator, opt=Adam(lr=1e-3)):
    gan_input = Input(shape=[100])
    x = generator(gan_input)
    gan_output = discriminator(x)
    model = Model(gan_input, gan_output)
    model.compile(loss='categorical_crossentropy', optimizer=opt)
    # model.summary()
    
    return model

# %%
def make_trainable(net, val):
    net.trainable = val
    for l in net.layers:
        l.trainable = val

# %%
from tqdm import tqdm

def train(step=3000, BATCH_SIZE=128):
    for e in tqdm(range(step)):
        # 1. バッチの学習で利用する画像の選択 
        # バッチサイズの分だけランダムに画像を選択
        image_batch = X_train[np.random.randint(0,X_train.shape[0],size=BATCH_SIZE),:,:,:]
        
        # バッチサイズの分だけランダムにノイズを生成し、generatorにより画像を生成
        noise_gen = np.random.uniform(0,1,size=[BATCH_SIZE,100])
        generated_images = generator.predict(noise_gen)
        
        # 2. Discriminatorの学習をonに切り替える
        # Discriminatorが学習するように変更
        make_trainable(discriminator,True)
        
        # 3. Generatorによる生成画像を用いてDiscriminatorの学習
        # X = (バッチサイズ分のデータセットの画像, バッチサイズ分の生成画像)
        X = np.concatenate((image_batch, generated_images))
        
        # y = (バッチサイズ分のTrue(本物), バッチサイズ分のFalse(偽物))
        y = np.zeros([2*BATCH_SIZE,2])
        y[:BATCH_SIZE,1] = 1
        y[BATCH_SIZE:,0] = 1      
        
        # Discriminatorのtrain
        discriminator.train_on_batch(X,y)
        
        # 4. Discriminatorの学習をoffに切り替える
        # Discriminatorが学習しないように変更
        make_trainable(discriminator,False)
    
        # 5. Generatorの学習
        # バッチサイズの分だけランダムにノイズを生成
        noise_gen = np.random.uniform(0,1,size=[BATCH_SIZE,100])
        
        # y = (バッチサイズ分のTrue(本物))
        # 実際には生成した画像なのでDiscriminatorとしては偽物と判断すべきだが、Genaratorの学習なので生成した画像を本物と判断するように学習させる
        y2 = np.zeros([BATCH_SIZE,2])
        y2[:,1] = 1
        
        # Generatorのtrain
        GAN.train_on_batch(noise_gen, y2 )

# %%
# データのロード

# サイズを合わせる
from PIL import Image, ImageOps

list_pic_sayashi = []
for p in list_pictures('this_is_sayashi'):
    list_pic_sayashi.append(load_img(p).resize((100, 100), Image.LANCZOS))

list_pic_sayashi_2 = []
for p in range(len(list_pic_sayashi)):
    list_pic_sayashi_2.append(ImageOps.mirror(list_pic_sayashi[p]))
    
list_pic_sayashi.extend(list_pic_sayashi_2)

X0 = np.empty((len(list_pic_sayashi),100,100,3))
Y0 = []

#　鞘師の画像(0)
for i, picture in enumerate(list_pic_sayashi):
    img_is_sayashi = img_to_array(picture)
    X0[i,:,:,:] = img_is_sayashi
    
    Y0.append(0)
Y0 = np.array(Y0)
list_pic_sayashi[0]
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FE1538A09B0>

# %%
# サイズを合わせる
from PIL import Image

list_pic_sayumi = []
for p in list_pictures('this_is_sayumi/this_is_sayumi'):
    list_pic_sayumi.append(load_img(p).resize((100, 100), Image.LANCZOS))

list_pic_sayumi_2 = []
for p in range(len(list_pic_sayumi)):
    list_pic_sayumi_2.append(ImageOps.mirror(list_pic_sayumi[p]))

list_pic_sayumi.extend(list_pic_sayumi_2)

X1 = np.empty((len(list_pic_sayumi),100,100,3))
Y1 = []

#　道重の画像(1)
for i, picture in enumerate(list_pic_sayumi):
    img_is_sayumi = img_to_array(picture)
    X1[i,:,:,:] = img_is_sayumi
    
    Y1.append(1)
Y1 = np.array(Y1)
list_pic_sayumi[0]
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FE153883438>

# %%
# サイズを合わせる
from PIL import Image

list_pic_karin = []
for p in list_pictures('this_is_karin/tihs_is_karin'):
    list_pic_karin.append(load_img(p).resize((100, 100), Image.LANCZOS))

list_pic_karin_2 = []
for p in range(len(list_pic_karin)):
    list_pic_karin_2.append(ImageOps.mirror(list_pic_karin[p]))

list_pic_karin.extend(list_pic_karin_2)

X2 = np.empty((len(list_pic_karin),100,100,3))
Y2 = []

#　佳林の画像(2)
for i, picture in enumerate(list_pic_karin):
    img_is_karin = img_to_array(picture)
    X2[i,:,:,:] = img_is_karin
    
    Y2.append(2)
Y2 = np.array(Y2)
list_pic_karin[0]
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FE152E61F60>

# %%
X_train = np.concatenate((X0, X1, X2))
array_to_img(X_train[600])
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FE1538A0278>

# %%
X_train = X_train/ 255
X_train
# Out:
# array([[[[0.58823529, 0.61568627, 0.71764706],
#          [0.60784314, 0.65098039, 0.7372549 ],
#          [0.59215686, 0.64313725, 0.70980392],
#          ...,
#          [0.81960784, 0.7372549 , 0.77254902],
#          [0.82745098, 0.79215686, 0.80392157],
#          [0.87843137, 0.8627451 , 0.85882353]],
#
#         [[0.44705882, 0.4745098 , 0.58431373],
#          [0.52941176, 0.57254902, 0.65882353],
#          [0.57254902, 0.62352941, 0.69803922],
#          ...,
#          [0.74901961, 0.63921569, 0.68627451],
#          [0.78823529, 0.72941176, 0.74901961],
#          [0.8627451 , 0.82745098, 0.83137255]],
#
#         [[0.27843137, 0.31764706, 0.42352941],
#          [0.40392157, 0.45098039, 0.5372549 ],
#          [0.51764706, 0.56862745, 0.64313725],
#          ...,
#          [0.74509804, 0.60392157, 0.65882353],
#          [0.79607843, 0.70588235, 0.74509804],
#          [0.89411765, 0.83529412, 0.85490196]],
#
#         ...,
#
#         [[0.07843137, 0.07843137, 0.07843137],
#          [0.0745098 , 0.0745098 , 0.0745098 ],
#          [0.06666667, 0.06666667, 0.06666667],
#          ...,
#          [0.20392157, 0.17647059, 0.14509804],
#          [0.04705882, 0.07843137, 0.08627451],
#          [0.07843137, 0.07843137, 0.10980392]],
#
#         [[0.08627451, 0.08627451, 0.08627451],
#          [0.07843137, 0.07843137, 0.07843137],
#          [0.07058824, 0.07058824, 0.07058824],
#          ...,
#          [0.25882353, 0.21176471, 0.16470588],
#          [0.0745098 , 0.09019608, 0.08627451],
#          [0.07843137, 0.0745098 , 0.09803922]],
#
#         [[0.0745098 , 0.0745098 , 0.0745098 ],
#          [0.06666667, 0.06666667, 0.06666667],
#          [0.0627451 , 0.0627451 , 0.0627451 ],
#          ...,
#          [0.30196078, 0.23137255, 0.17647059],
#          [0.09411765, 0.10196078, 0.08235294],
#          [0.07843137, 0.0745098 , 0.09411765]]],
#
#
#        [[[0.31372549, 0.27843137, 0.29019608],
#          [0.23137255, 0.20784314, 0.21568627],
#          [0.18431373, 0.16470588, 0.18039216],
#          ...,
#          [0.99215686, 0.99607843, 1.        ],
#          [0.99215686, 0.99607843, 1.        ],
#          [0.99215686, 0.99607843, 1.        ]],
#
#         [[0.26666667, 0.24313725, 0.25098039],
#          [0.20392157, 0.18823529, 0.19215686],
#          [0.19215686, 0.17254902, 0.18823529],
#          ...,
#          [0.99215686, 0.99607843, 1.        ],
#          [0.99215686, 0.99607843, 1.        ],
#          [0.99215686, 0.99607843, 1.        ]],
#
#         [[0.21960784, 0.20392157, 0.20784314],
#          [0.16862745, 0.16078431, 0.17254902],
#          [0.19215686, 0.18431373, 0.20392157],
#          ...,
#          [0.99215686, 0.99607843, 1.        ],
#          [0.99215686, 0.99607843, 1.        ],
#          [0.99215686, 0.99607843, 1.        ]],
#
#         ...,
#
#         [[0.99215686, 0.99607843, 1.        ],
#          [0.99215686, 0.99607843, 1.        ],
#          [0.99215686, 0.99607843, 1.        ],
#
0.        ],
#          [0.        , 0.        , 0.        ],
#          ...,
#          [0.81176471, 0.81176471, 0.77254902],
#          [0.81568627, 0.81568627, 0.77647059],
#          [0.81960784, 0.81960784, 0.78039216]]],
#
#
#        [[[0.63529412, 0.70196078, 0.63921569],
#          [0.63529412, 0.70588235, 0.64313725],
#          [0.63921569, 0.70980392, 0.64705882],
#          ...,
#          [0.8627451 , 0.93333333, 0.93333333],
#          [0.85490196, 0.92941176, 0.91372549],
#          [0.84313725, 0.92156863, 0.88627451]],
#
#         [[0.64313725, 0.68235294, 0.63921569],
#          [0.63921569, 0.67843137, 0.63529412],
#          [0.63137255, 0.67058824, 0.62745098],
#          ...,
#          [0.85882353, 0.92156863, 0.90980392],
#          [0.84313725, 0.90980392, 0.87843137],
#          [0.82745098, 0.89411765, 0.85490196]],
#
#         [[0.63921569, 0.69019608, 0.65490196],
#          [0.61568627, 0.66666667, 0.63137255],
#          [0.57647059, 0.62745098, 0.59215686],
#          ...,
#          [0.84313725, 0.90980392, 0.88627451],
#          [0.81960784, 0.89019608, 0.84313725],
#          [0.80784314, 0.87843137, 0.82352941]],
#
#         ...,
#
#         [[0.8       , 0.8       , 0.79215686],
#          [0.8       , 0.80784314, 0.78823529],
#          [0.79215686, 0.81176471, 0.78823529],
#          ...,
#          [0.4627451 , 0.55686275, 0.59607843],
#          [0.32156863, 0.45098039, 0.47843137],
#          [0.27058824, 0.42745098, 0.43529412]],
#
#         [[0.79607843, 0.80392157, 0.79215686],
#          [0.78823529, 0.80784314, 0.78431373],
#          [0.78431373, 0.81176471, 0.78431373],
#          ...,
#          [0.48235294, 0.57254902, 0.59607843],
#          [0.36862745, 0.48235294, 0.49803922],
#          [0.24705882, 0.4       , 0.39607843]],
#
#         [[0.79215686, 0.8       , 0.78823529],
#          [0.78823529, 0.80784314, 0.78431373],
#          [0.78431373, 0.81176471, 0.78431373],
#          ...,
#          [0.57647059, 0.65882353, 0.67843137],
#          [0.55686275, 0.66666667, 0.67058824],
#          [0.49803922, 0.63529412, 0.61960784]]]])

# %%
# それぞれのネットワークのインスタンスを生成
generator = Generator()
discriminator = Discriminator(X_train.shape[1:])
make_trainable(discriminator, False)
GAN = combined_network(generator, discriminator)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 100)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 640000)            64640000
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 640000)            2560000
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 640000)            0
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 50, 50, 256)       0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 100, 100, 256)     0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 100, 100, 128)     131200
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 100, 100, 128)     512
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 100, 100, 128)     0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 100, 100, 64)      32832
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 100, 100, 64)      256
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 100, 100, 64)      0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 100, 100, 32)      18464
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 100, 100, 32)      128
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 100, 100, 32)      0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 100, 100, 3)       867
# _________________________________________________________________
# activation_2 (Activation)    (None, 100, 100, 3)       0
# =================================================================
# Total params: 67,384,259
# Trainable params: 66,103,811
# Non-trainable params: 1,280,448
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 100, 100, 3)       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 50, 50, 32)        896
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 50, 50, 32)        0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 50, 50, 32)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 25, 25, 64)        18496
# _________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)   (None, 25, 25, 64)        0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 25, 25, 64)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 13, 13, 128)       73856
# _________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)   (None, 13, 13, 128)       0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 13, 13, 128)       0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 7, 7, 256)         295168
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 7, 7, 256)         0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 7, 7, 256)         0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 4, 4, 512)         1180160
# _________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)   (None, 4, 4, 512)         0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               2097408
# _________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)   (None, 256)               0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 3,666,498
# Trainable params: 3,666,498
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 100)               0
# _________________________________________________________________
# model_4 (Model)              (None, 100, 100, 3)       67384259
# _________________________________________________________________
# model_5 (Model)              (None, 2)                 3666498
# =================================================================
# Total params: 71,050,757
# Trainable params: 66,103,811
# Non-trainable params: 4,946,946
# _________________________________________________________________

# %%
# train関数で学習を行うstepを大きくすると学習をより多く行います
train(step=2000, BATCH_SIZE=32)
# Out:
# 100%|██████████| 2000/2000 [25:55<00:00,  1.28it/s]

# %%
from google.colab import files

x = 3

noise = np.random.uniform(0,1,size=[3, 100])
generated_images = generator.predict(noise)

img = []

for i in range(3):
    img.append(array_to_img(generated_images[i],scale=True))
    img[i].save('img{0}.jpg'.format(str(i)))
    files.download('img{0}.jpg'.format(str(i)))

# %%
train(step=4000, BATCH_SIZE=32)
# Out:
# 100%|██████████| 4000/4000 [51:49<00:00,  1.29it/s]

# %%
x = 3

noise = np.random.uniform(0,1,size=[x, 100])
generated_images = generator.predict(noise)

img = []

for i in range(x):
    img.append(array_to_img(generated_images[i],scale=True))
    img[i].save('img{0}.jpg'.format(str(i)))
    files.download('img{0}.jpg'.format(str(i)))

# %%
train(step=4000, BATCH_SIZE=32)
# Out:
# 100%|██████████| 4000/4000 [51:48<00:00,  1.28it/s]

# %%
x = 3

noise = np.random.uniform(0,1,size=[x, 100])
generated_images = generator.predict(noise)

img = []

for i in range(x):
    img.append(array_to_img(generated_images[i],scale=True))
    img[i].save('img{0}.jpg'.format(str(i)))
    files.download('img{0}.jpg'.format(str(i)))

# %%
train(step=4000, BATCH_SIZE=32)
# Out:
# 100%|██████████| 4000/4000 [51:46<00:00,  1.28it/s]

# %%
x = 3

noise = np.random.uniform(0,1,size=[x, 100])
generated_images = generator.predict(noise)

img = []

for i in range(x):
    img.append(array_to_img(generated_images[i],scale=True))
    img[i].save('img{0}.jpg'.format(str(i)))
    files.download('img{0}.jpg'.format(str(i)))

# %%
generator.save('sayashi3g.h5')
files.download('sayashi3g.h5')
discriminator.save('sayashi3d.h5')
files.download('sayashi3d.h5')
# Out:
# ----------------------------------------
# Exception happened during processing of request from ('::ffff:127.0.0.1', 42132, 0, 0)
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/socketserver.py", line 317, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/usr/lib/python3.6/socketserver.py", line 348, in process_request
#     self.finish_request(request, client_address)
#   File "/usr/lib/python3.6/socketserver.py", line 361, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/usr/lib/python3.6/socketserver.py", line 696, in __init__
#     self.handle()
#   File "/usr/lib/python3.6/http/server.py", line 418, in handle
#     self.handle_one_request()
#   File "/usr/lib/python3.6/http/server.py", line 406, in handle_one_request
#     method()
#   File "/usr/lib/python3.6/http/server.py", line 639, in do_GET
#     self.copyfile(f, self.wfile)
#   File "/usr/lib/python3.6/http/server.py", line 800, in copyfile
#     shutil.copyfileobj(source, outputfile)
#   File "/usr/lib/python3.6/shutil.py", line 82, in copyfileobj
#     fdst.write(buf)
#   File "/usr/lib/python3.6/socketserver.py", line 775, in write
#     self._sock.sendall(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
# ----------------------------------------
# ----------------------------------------
# Exception happened during processing of request from ('::ffff:127.0.0.1', 38174, 0, 0)
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/socketserver.py", line 317, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/usr/lib/python3.6/socketserver.py", line 348, in process_request
#     self.finish_request(request, client_address)
#   File "/usr/lib/python3.6/socketserver.py", line 361, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/usr/lib/python3.6/socketserver.py", line 696, in __init__
#     self.handle()
#   File "/usr/lib/python3.6/http/server.py", line 418, in handle
#     self.handle_one_request()
#   File "/usr/lib/python3.6/http/server.py", line 406, in handle_one_request
#     method()
#   File "/usr/lib/python3.6/http/server.py", line 639, in do_GET
#     self.copyfile(f, self.wfile)
#   File "/usr/lib/python3.6/http/server.py", line 800, in copyfile
#     shutil.copyfileobj(source, outputfile)
#   File "/usr/lib/python3.6/shutil.py", line 82, in copyfileobj
#     fdst.write(buf)
#   File "/usr/lib/python3.6/socketserver.py", line 775, in write
#     self._sock.sendall(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
# ----------------------------------------

# %%
train(step=4000, BATCH_SIZE=32)
# Out:
#   7%|▋         | 271/4000 [03:30<48:09,  1.29it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-c382ec293ea6> in <module>()
# ----> 1 train(step=4000, BATCH_SIZE=32)
#
# <ipython-input-17-ce5b00598dd6> in train(step, BATCH_SIZE)
#      41
#      42         # Generatorのtrain
# ---> 43         GAN.train_on_batch(noise_gen, y2 )
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1881             ins = x + y + sample_weights
#    1882         self._make_train_function()
# -> 1883         outputs = self.train_function(ins)
#    1884         if len(outputs) == 1:
#    1885             return outputs[0]
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2480         session = get_session()
#    2481         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2482                               **self.session_kwargs)
#    2483         return updated[:len(self.outputs)]
#    2484
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     885     try:
#     886       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 887                          run_metadata_ptr)
#     888       if run_metadata:
#     889         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1108     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1109       results = self._do_run(handle, final_targets, final_fetches,
# -> 1110                              feed_dict_tensor, options, run_metadata)
#    1111     else:
#    1112       results = []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1284     if handle is None:
#    1285       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1286                            run_metadata)
#    1287     else:
#    1288       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1290   def _do_call(self, fn, *args):
#    1291     try:
# -> 1292       return fn(*args)
#    1293     except errors.OpError as e:
#    1294       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1275       self._extend_graph()
#    1276       return self._call_tf_sessionrun(
# -> 1277           options, feed_dict, fetch_list, target_list, run_metadata)
#    1278
#    1279     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1365     return tf_session.TF_SessionRun_wrapper(
#    1366         self._session, options, feed_dict, fetch_list, target_list,
# -> 1367         run_metadata)
#    1368
#    1369   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
x = 3

noise = np.random.uniform(0,1,size=[x, 100])
generated_images = generator.predict(noise)

img = []

for i in range(x):
    img.append(array_to_img(generated_images[i],scale=True))
    img[i].save('img{0}.jpg'.format(str(i)))
    files.download('img{0}.jpg'.format(str(i)))

# %%
generator.save('sayashi3g.h5')
files.download('sayashi3g.h5')
discriminator.save('sayashi3d.h5')
files.download('sayashi3d.h5')

# %%
train(step=10000, BATCH_SIZE=32)

# %%
x = 3

noise = np.random.uniform(0,1,size=[x, 100])
generated_images = generator.predict(noise)

img = []

for i in range(x):
    img.append(array_to_img(generated_images[i],scale=True))
    img[i].save('img{0}.jpg'.format(str(i)))
    files.download('img{0}.jpg'.format(str(i)))

# %%
generator.save('sayashi3g.h5')
files.download('sayashi3g.h5')
discriminator.save('sayashi3d.h5')
files.download('sayashi3d.h5')
